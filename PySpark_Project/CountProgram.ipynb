
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
text_flat=in_text.flatMap(lambda x: x.split(' '))

# %%
text_flat.collect()
# Out:
# ['Kurd',
#  'Laßwitz',
#  '',
#  '',
#  'Bis',
#  'zum',
#  'Nullpunkt',
#  'des',
#  'Seins',
#  '',
#  '',
#  'Erzählung',
#  'aus',
#  'dem',
#  'Jahre',
#  '2371',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Das',
#  'Geruchsklavier',
#  '',
#  '',
#  '',
#  '',
#  'Aromasia',
#  'saß',
#  'im',
#  'Garten',
#  'ihres',
#  'Hauses',
#  'und',
#  'sah',
#  'träumerisch',
#  'ins',
#  'Blau',
#  'des',
#  'schönen',
#  'Sommertages',
#  'vom',
#  'Jahre',
#  '2371.',
#  'Sie',
#  'folgte',
#  'mit',
#  'ihren',
#  'Blicken',
#  'den',
#  'kleinen',
#  'dunklen',
#  'Wolken,',
#  'welche',
#  'sich',
#  'hier',
#  'und',
#  'da',
#  'plötzlich',
#  'in',
#  'der',
#  'Atmosphäre',
#  'bildeten',
#  'und',
#  'einen',
#  'Regenguß',
#  'herabströmen',
#  'ließen;',
#  'oder',
#  'sie',
#  'spähte',
#  'nach',
#  'den',
#  'fliegenden',
#  'Wagen',
#  'und',
#  'Luftvelozipeden',
#  'aus,',
#  'die',
#  'zu',
#  'ihren',
#  'Füßen',
#  'in',
#  'buntem',
#  'Gewühle',
#  'die',
#  'breite',
#  'Straße',
#  'erfüllten.',
#  'Denn',
#  'der',
#  'Garten',
#  'Aromasias',
#  'befand',
#  'sich',
#  'in',
#  'der',
#  'luftigen',
#  'Höhe',
#  'von',
#  'ungefähr',
#  'hundert',
#  'Metern',
#  'über',
#  'dem',
#  'Erdboden',
#  'auf',
#  'dem',
#  'Dache',
#  'ihres',
#  'Hauses.',
#  '',
#  'Man',
#  'sah',
#  'sich',
#  'genötigt,',
#  'die',
#  'Wohnhäuser',
#  'in',
#  'so',
#  'gewaltigen',
#  'Dimensionen',
#  'aufzutürmen',
#  'und',
#  'die',
#  'Gärten',
#  'über',
#  'ihnen',
#  'anzubringen,',
#  'da',
#  'man',
#  'den',
#  'Raum',
#  'der',
#  'ebenen',
#  'Erde',
#  'dem',
#  'Ackerbau',
#  'vorbehalten',
#  'mußte.',
#  'So',
#  'reichbevölkert',
#  'war',
#  'der',
#  'Erdball,',
#  'daß',
#  'man',
#  'jedes',
#  'Plätzchen',
#  'dem',
#  'Anbau',
#  'der',
#  'Halmfrucht',
#  'und',
#  'der',
#  'Ernährung',
#  'des',
#  'Schlachtviehs',
#  'widmen',
#  'mußte,',
#  'um',
#  'die',
#  'Gefahr',
#  'einer',
#  'Hungersnot',
#  'abzuwenden.',
#  '',
#  'So',
#  'wogten',
#  'denn',
#  'am',
#  'Boden',
#  'die',
#  'Getreidefelder,',
#  'wo',
#  'immer',
#  'Luft',
#  'und',
#  'Licht',
#  'es',
#  'gestatteten;',
#  'darüber',
#  'standen',
#  'auf',
#  'festen,',
#  'hohen',
#  'Säulen',
#  'die',
#  'Gebäude',
#  'der',
#  'Menschen,',
#  'in',
#  'deren',
#  'unteren',
#  'Stockwerken',
#  'die',
#  'Industrie',
#  'ihr',
#  'geschäftiges',
#  'Leben',
#  'trieb.',
#  'Weiter',
#  'oben',
#  'folgten',
#  'Privatwohnungen,',
#  'und',
#  'die',
#  'Krone',
#  'des',
#  'Ganzen',
#  'bildeten',
#  'anmutige',
#  'Gärten,',
#  'deren',
#  'freie',
#  'und',
#  'gesunde',
#  'Lage',
#  'sie',
#  'zum',
#  'beliebtesten',
#  'Aufenthalte',
#  'machte.',
#  '',
#  'Die',
#  'Aufeinanderfolge',
#  'von',
#  'fünfzehn',
#  'bis',
#  'fünfundzwanzig',
#  'Stockwerken',
#  'war',
#  'übrigens',
#  'durchaus',
#  'nicht',
#  'mit',
#  'Unbequemlichkeiten',
#  'verbunden;',
#  'denn',
#  'der',
#  'Luftwagen',
#  'war',
#  'das',
#  'gewöhnliche',
#  'Verkehrsmittel;',
#  'und',
#  'wollte',
#  'man',
#  'wirklich',
#  'einmal',
#  'zu',
#  'Fuß',
#  'ausgehen,',
#  'so',
#  'fanden',
#  'sich',
#  'die',
#  'Treppen',
#  'durch',
#  'treffliche',
#  'Hebe',
#  '—',
#  'und',
#  'Senkvorrichtungen',
#  'ersetzt.',
#  'In',
#  'den',
#  'Städten',
#  '–',
#  'und',
#  'deren',
#  'gab',
#  'es',
#  'unzählige',
#  '–',
#  'waren',
#  'außerdem',
#  'die',
#  'einzelnen',
#  'Stockwerke',
#  'längs',
#  'der',
#  'Straßenfront',
#  'durch',
#  'Galerien',
#  'verbunden;',
#  'ihre',
#  'Benutzung',
#  'war',
#  'bequem',
#  'und',
#  'praktisch,',
#  'aber',
#  '–',
#  'wie',
#  'es',
#  'so',
#  'geht,',
#  'man',
#  'weiß',
#  'nicht',
#  'immer,',
#  'warum',
#  '–',
#  'bei',
#  'der',
#  'feinen',
#  'Gesellschaft',
#  'galt',
#  'sie',
#  'nicht',
#  'für',
#  'standesgemäß;',
#  'sie',
#  'diente',
#  'nur',
#  'dem',
#  'kleinen',
#  'Geschäftsverkehr',
#  'und',
#  'Hausgebrauche.',
#  'Ebenso',
#  'hielt',
#  'man',
#  'es',
#  'für',
#  'unpassend,',
#  'ja,',
#  'es',
#  'war',
#  'sogar',
#  'straßenpolizeilich',
#  'verboten,',
#  'innerhalb',
#  'der',
#  'Stadt',
#  'mit',
#  'den',
#  'leichten',
#  'Fahrzeugen',
#  'sich',
#  'höher',
#  'als',
#  'die',
#  'Dächer',
#  'der',
#  'Häuser',
#  'zu',
#  'erheben',
#  'oder',
#  'quer',
#  'über',
#  'Privatbesitz',
#  'durch',
#  'die',
#  'Luft',
#  'zu',
#  'fliegen.',
#  'Natürlich',
#  'gab',
#  'es',
#  'auch',
#  'immer',
#  'mutwillige',
#  'und',
#  'unartige',
#  'Übertreter',
#  'dieser',
#  'Sitte,',
#  'und',
#  'wenn',
#  'es',
#  'früher,',
#  'im',
#  'rohen',
#  'Neu-Mittelalter,',
#  'der',
#  'Übermut',
#  'der',
#  'männlichen',
#  'Jugend',
#  'nicht',
#  'verschmähte,',
#  'in',
#  'weinseliger',
#  'Nacht',
#  'allerlei',
#  'Unfug',
#  'an',
#  'Schildern',
#  'und',
#  'Hausklingeln',
#  'zu',
#  'verüben,',
#  'so',
#  'kam',
#  'es',
#  'auch',
#  'heute',
#  'wohl',
#  'vor,',
#  'daß',
#  'sich',
#  'am',
#  'Morgen',
#  'ein',
#  'Fenster',
#  'mit',
#  'schönen',
#  'Bildern',
#  'verklebt',
#  'fand',
#  'oder',
#  'ein',
#  'wohlverpacktes',
#  'Bukett',
#  'zum',
#  'Schornstein',
#  'hereinspazierte.',
#  '',
#  'Aromasia',
#  'Duftemann',
#  'Ozodes,',
#  'die',
#  'allverehrte',
#  'Künstlerin,',
#  'seufzte',
#  'leise,',
#  'nachdem',
#  'sie',
#  'wieder',
#  'vergebens',
#  'in',
#  'der',
#  'Menge',
#  'der',
#  'Luft-Droschken',
#  'nach',
#  'dem',
#  'Ziele',
#  'ihrer',
#  'Sehnsucht',
#  'gesucht',
#  'hatte.',
#  '',
#  '»Wo',
#  'nur',
#  'Oxygen',
#  'bleiben',
#  'mag?«',
#  'klagte',
#  'sie',
#  'sanft',
#  'in',
#  'den',
#  'wohltönenden',
#  'Lauten',
#  'der',
#  'deutschen',
#  'Sprache.',
#  'Denn',
#  'wenn',
#  'man',
#  'auch',
#  'im',
#  'gewöhnlichen',
#  'Verkehre',
#  'sich',
#  'fast',
#  'ausschließlich',
#  'der',
#  'neu',
#  'eingeführten',
#  'Universalsprache',
#  'zu',
#  'bedienen',
#  'pflegte,',
#  'so',
#  'sprach',
#  'man',
#  'doch',
#  'die',
#  'zarten',
#  'Empfindungen',
#  'des',
#  'Herzens',
#  'in',
#  'den',
#  'süßen',
#  'Klängen',
#  'der',
#  'ursprünglichen',
#  'Muttersprache',
#  'aus.',
#  '',
#  '»Merkwürdig«,',
#  'fuhr',
#  'sie',
#  'fort,',
#  '»daß',
#  'er',
#  'nicht',
#  'nach',
#  'seiner',
#  'Gewohnheit',
#  'längst',
#  'zu',
#  'mir',
#  'geeilt.',
#  'Schon',
#  'neun',
#  'Uhr',
#  'vierundachtzig',
#  'Minuten',
#  'siebzig',
#  'Sekunden?',
#  'Und',
#  'auch',
#  'Magnet',
#  'kommt',
#  'nicht',
#  '–',
#  'aber',
#  'die',
#  'Dichter',
#  'sind',
#  'unpünktlich.',
#  'Er',
#  'sinnt',
#  'gewiß',
#  'auf',
#  'ein',
#  'Grunzulett;',
#  'und',
#  'dazu',
#  'braucht',
#  'er',
#  'Zeit.«',
#  '',
#  'Das',
#  'Grunzulett',
#  'ist',
#  'nämlich',
#  'eine',
#  'neue',
#  'Dichtungsform,',
#  'welche',
#  'die',
#  'Vorzüge',
#  'des',
#  'Sonetts,',
#  'des',
#  'Gasels,',
#  'der',
#  'alcäischen',
#  'Strophe',
#  'und',
#  'des',
#  'Familienromans',
#  'in',
#  'sich',
#  'vereinigt,',
#  'leider',
#  'aber',
#  'nur',
#  'in',
#  'der',
#  'modernen',
#  'Universalsprache',
#  'zu',
#  'leisten',
#  'ist,',
#  'weil',
#  'seine',
#  'Hauptschönheit',
#  'darin',
#  'besteht,',
#  'daß',
#  'Alliteration',
#  'und',
#  'Reim',
#  'durch',
#  'eigene',
#  'Selbstvernichtung',
#  'sich',
#  'zu',
#  'einer',
#  'neuen',
#  'Form,',
#  'der',
#  '»in',
#  'sich',
#  'zurückkehrenden',
#  'unendlichen',
#  'Lautquetsche«,',
#  'verbinden.',
#  '',
#  'Jetzt',
#  'griff',
#  'Aromasia',
#  'nach',
#  'dem',
#  'neben',
#  'ihr',
#  'liegenden',
#  'Doppelfernrohr',
#  'und',
#  'sah',
#  'scharf',
#  'nach',
#  'einer',
#  'Stelle',
#  'der',
#  'Vorstadt,',
#  'welche',
#  'ungefähr',
#  '25',
#  'Kilometer',
#  'von',
#  'ihrem',
#  'Standpunkte',
#  'entfernt',
#  'sein',
#  'mochte;',
#  'eine',
#  'jener',
#  'schon',
#  'erwähnten',
#  'kleinen',
#  'Wolken',
#  'erhob',
#  'sich',
#  'gerade',
#  'darüber.',
#  '',
#  '»Es',
#  'ist',
#  'Oxygen«,',
#  'sagte',
#  'sie',
#  'beruhigt',
#  'bei',
#  'sich,',
#  'indem',
#  'sie',
#  'das',
#  'Fernrohr',
#  'sinken',
#  'ließ.',
#  '»Ich',
#  'erkenne',
#  'seine',
#  'Maschine.',
#  'Er',
#  'ist',
#  'also',
#  'beschäftigt',
#  'und',
#  'wird',
#  'erst',
#  'später',
#  'erscheinen.',
#  'So',
#  'muß',
#  'ich',
#  'mir',
#  'denn',
#  'bis',
#  'zu',
#  'seiner',
#  'Ankunft',
#  'die',
#  'Zeit',
#  'nach',
#  'eigenem',
#  'Geschmack',
#  'vertreiben.',
#  'Wohlauf,',
#  'meine',
#  'getreue',
#  'Kunst!',
#  'Ihr',
#  'gewaltigen',
#  'Gedanken',
#  'der',
#  'großen',
#  'Duftmeister',
#  'sollt',
#  'mir',
#  'die',
#  'schleichende',
#  'Stunde',
#  'verkürzen',
#  'und',
#  'meine',
#  'Seele',
#  'in',
#  'die',
#  'Regionen',
#  'wunschlosen',
#  'Wahnes',
#  'tragen!«',
#  '',
#  'Sie',
#  'trat',
#  'auf',
#  'die',
#  'Versenkung',
#  'und',
#  'befand',
#  'sich',
#  'wenige',
#  'Augenblicke',
#  'später',
#  'in',
#  'ihrem',
#  'geschmackvoll',
#  'eingerichteten',
#  'Zimmer.',
#  'Ein',
#  'Instrument',
#  'in',
#  'der',
#  'Gestalt',
#  'eines',
#  'Pianinos',
#  'stand',
#  'in',
#  'der',
#  'Mitte.',
#  'Sie',
#  'öffnete',
#  'den',
#  'Deckel',
#  'und',
#  'griff',
#  'in',
#  'die',
#  'Klaviatur',
#  'des',
#  'Ododions;',
#  'bald',
#  'schwelgte',
#  'sie',
#  'in',
#  'den',
#  'Wonnedüften',
#  'einer',
#  'Phantasie',
#  'von',
#  'Riechmann,',
#  'und',
#  'harmonische',
#  'Wohlgerüche',
#  'durchströmten',
#  'das',
#  'Zimmer.',
#  '',
#  'Das',
#  'Ododion',
#  'oder',
#  'Geruchsklavier',
#  'wurde',
#  'im',
#  'Jahre',
#  '2094',
#  'von',
#  'einem',
#  'Italiener',
#  'Namens',
#  'Odorato',
#  'erfunden',
#  'und',
#  'im',
#  'Laufe',
#  'der',
#  'Zeit,',
#  'entsprechend',
#  'den',
#  'Fortschritten',
#  'der',
#  'Chemie,',
#  'bedeutend',
#  'vervollkommnet.',
#  'Das',
#  'Instrument',
#  'unserer',
#  'Künsterlin',
#  'war',
#  'aus',
#  'einer',
#  'deutschen',
#  'Fabrik',
#  'und',
#  'zeichnete',
#  'sich',
#  'durch',
#  'seinen',
#  'großen',
#  'Umfang',
#  'an',
#  'Gerüchen',
#  'aus;',
#  'es',
#  'reichte',
#  'von',
#  'dem',
#  'als',
#  'unterste',
#  'Duftstufe',
#  'angenommenen',
#  'dumpfen',
#  'Keller',
#  '—',
#  'und',
#  'Modergeruche',
#  'bis',
#  'zum',
#  'Zwiblozin,',
#  'einem',
#  'erst',
#  'im',
#  'Jahre',
#  '2369',
#  'entdeckten',
#  'äußerst',
#  'zarten',
#  'Odeur.',
#  'Jeder',
#  'Druck',
#  'auf',
#  'eine',
#  'Taste',
#  'öffnete',
#  'einen',
#  'entsprechenden',
#  'Gasometer,',
#  'und',
#  'künstliche',
#  'mechanische',
#  'Vorrichtungen',
#  'sorgten',
#  'für',
#  'die',
#  'Dämpfung,',
#  'Ausbreitung',
#  'und',
#  'Zusammenwirkung',
#  'der',
#  'Düfte.',
#  '',
#  'Nachdem',
#  'man',
#  'die',
#  'Musik',
#  'auf',
#  'einen',
#  'solchen',
#  'Höhepunkt',
#  'der',
#  'Vervollkommnung',
#  'gebracht',
#  'hatte,',
#  'daß',
#  'das',
#  'Ohr',
#  'unmöglich',
#  'mehr',
#  'ertragen',
#  'konnte,',
#  'hatte',
#  'man',
#  'seine',
#  'Aufmerksamkeit',
#  'der',
#  'so',
#  'sehr',
#  'vernachlässigten',
#  'Nase',
#  'zugewandt.',
#  'Die',
#  'Feinheit',
#  'des',
#  'Geruchsorgans',
#  'war',
#  'freilich',
#  'bei',
#  'der',
#  'Menschheit',
#  'in',
#  'der',
#  'Rückbildung',
#  'begriffen;',
#  'aber',
#  'warum',
#  'sollte',
#  'man',
#  'diese',
#  'nicht',
#  'steuern',
#  'können?',
#  'Kein',
#  'anderer',
#  'Sinn',
#  'wirkt',
#  'gleich',
#  'lebhaft',
#  'auf',
#  'unsere',
#  'Ideenassoziation',
#  'wie',
#  'der',
#  'des',
#  'Geruchs;',
#  'es',
#  'lag',
#  'nahe,',
#  'ihn',
#  'künstlerisch',
#  'dazu',
#  'zu',
#  'verwerten,',
#  'bestimmte',
#  'Vorstellungen',
#  'und',
#  'Empfindungen',
#  'in',
#  'uns',
#  'hervorzurufen.',
#  'Man',
#  'studierte',
#  'die',
#  'Eigentümlichkeiten',
#  'und',
#  'Wirkungen',
#  'der',
#  'Gerüche,',
#  'fand',
#  'die',
#  'Gesetze',
#  'ihrer',
#  'Harmonie',
#  'und',
#  'Disharmonie,',
#  'anfänglich',
#  'auf',
#  'empirischem,',
#  'später',
#  'auch',
#  'auf',
#  'theoretischem',
#  'Wege,',
#  'die',
#  'Chemie',
#  'stellte',
#  'immer',
#  'wohlfeiler',
#  'die',
#  'notwendigen',
#  'Aromen',
#  'her,',
#  'und',
#  'nachdem',
#  'das',
#  'Ododion',
#  'erst',
#  'als',
#  'Kuriosum',
#  'gezeigt',
#  'und',
#  'auf',
#  'Rundreisen',
#  'durch',
#  'die',
#  'Städte',
#  'von',
#  'aller',
#  'Welt',
#  'angestaunt',
#  'worden',
#  'war,',
#  'bürgerte',
#  'es',
#  'sich',
#  'bald',
#  'in',
#  'den',
#  'Familien,',
#  'im',
#  'Privatkreise',
#  'ein.',
#  '',
#  'Die',
#  'größten',
#  'Duftmeister,',
#  'zuerst',
#  'Naso',
#  'Odorato,',
#  'dann',
#  'Stinkerling,',
#  ...]

# %%
text_flat=in_text.flatMap(lambda x: x.split(' '))\
                 .map(lambda x: (x,1))

# %%
text_flat.collect()
# Out:
# [('Kurd', 1),
#  ('Laßwitz', 1),
#  ('', 1),
#  ('', 1),
#  ('Bis', 1),
#  ('zum', 1),
#  ('Nullpunkt', 1),
#  ('des', 1),
#  ('Seins', 1),
#  ('', 1),
#  ('', 1),
#  ('Erzählung', 1),
#  ('aus', 1),
#  ('dem', 1),
#  ('Jahre', 1),
#  ('2371', 1),
#  ('', 1),
#  ('', 1),
#  ('', 1),
#  ('', 1),
#  ('', 1),
#  ('Das', 1),
#  ('Geruchsklavier', 1),
#  ('', 1),
#  ('', 1),
#  ('', 1),
#  ('', 1),
#  ('Aromasia', 1),
#  ('saß', 1),
#  ('im', 1),
#  ('Garten', 1),
#  ('ihres', 1),
#  ('Hauses', 1),
#  ('und', 1),
#  ('sah', 1),
#  ('träumerisch', 1),
#  ('ins', 1),
#  ('Blau', 1),
#  ('des', 1),
#  ('schönen', 1),
#  ('Sommertages', 1),
#  ('vom', 1),
#  ('Jahre', 1),
#  ('2371.', 1),
#  ('Sie', 1),
#  ('folgte', 1),
#  ('mit', 1),
#  ('ihren', 1),
#  ('Blicken', 1),
#  ('den', 1),
#  ('kleinen', 1),
#  ('dunklen', 1),
#  ('Wolken,', 1),
#  ('welche', 1),
#  ('sich', 1),
#  ('hier', 1),
#  ('und', 1),
#  ('da', 1),
#  ('plötzlich', 1),
#  ('in', 1),
#  ('der', 1),
#  ('Atmosphäre', 1),
#  ('bildeten', 1),
#  ('und', 1),
#  ('einen', 1),
#  ('Regenguß', 1),
#  ('herabströmen', 1),
#  ('ließen;', 1),
#  ('oder', 1),
#  ('sie', 1),
#  ('spähte', 1),
#  ('nach', 1),
#  ('den', 1),
#  ('fliegenden', 1),
#  ('Wagen', 1),
#  ('und', 1),
#  ('Luftvelozipeden', 1),
#  ('aus,', 1),
#  ('die', 1),
#  ('zu', 1),
#  ('ihren', 1),
#  ('Füßen', 1),
#  ('in', 1),
#  ('buntem', 1),
#  ('Gewühle', 1),
#  ('die', 1),
#  ('breite', 1),
#  ('Straße', 1),
#  ('erfüllten.', 1),
#  ('Denn', 1),
#  ('der', 1),
#  ('Garten', 1),
#  ('Aromasias', 1),
#  ('befand', 1),
#  ('sich', 1),
#  ('in', 1),
#  ('der', 1),
#  ('luftigen', 1),
#  ('Höhe', 1),
#  ('von', 1),
#  ('ungefähr', 1),
#  ('hundert', 1),
#  ('Metern', 1),
#  ('über', 1),
#  ('dem', 1),
#  ('Erdboden', 1),
#  ('auf', 1),
#  ('dem', 1),
#  ('Dache', 1),
#  ('ihres', 1),
#  ('Hauses.', 1),
#  ('', 1),
#  ('Man', 1),
#  ('sah', 1),
#  ('sich', 1),
#  ('genötigt,', 1),
#  ('die', 1),
#  ('Wohnhäuser', 1),
#  ('in', 1),
#  ('so', 1),
#  ('gewaltigen', 1),
#  ('Dimensionen', 1),
#  ('aufzutürmen', 1),
#  ('und', 1),
#  ('die', 1),
#  ('Gärten', 1),
#  ('über', 1),
#  ('ihnen', 1),
#  ('anzubringen,', 1),
#  ('da', 1),
#  ('man', 1),
#  ('den', 1),
#  ('Raum', 1),
#  ('der', 1),
#  ('ebenen', 1),
#  ('Erde', 1),
#  ('dem', 1),
#  ('Ackerbau', 1),
#  ('vorbehalten', 1),
#  ('mußte.', 1),
#  ('So', 1),
#  ('reichbevölkert', 1),
#  ('war', 1),
#  ('der', 1),
#  ('Erdball,', 1),
#  ('daß', 1),
#  ('man', 1),
#  ('jedes', 1),
#  ('Plätzchen', 1),
#  ('dem', 1),
#  ('Anbau', 1),
#  ('der', 1),
#  ('Halmfrucht', 1),
#  ('und', 1),
#  ('der', 1),
#  ('Ernährung', 1),
#  ('des', 1),
#  ('Schlachtviehs', 1),
#  ('widmen', 1),
#  ('mußte,', 1),
#  ('um', 1),
#  ('die', 1),
#  ('Gefahr', 1),
#  ('einer', 1),
#  ('Hungersnot', 1),
#  ('abzuwenden.', 1),
#  ('', 1),
#  ('So', 1),
#  ('wogten', 1),
#  ('denn', 1),
#  ('am', 1),
#  ('Boden', 1),
#  ('die', 1),
#  ('Getreidefelder,', 1),
#  ('wo', 1),
#  ('immer', 1),
#  ('Luft', 1),
#  ('und', 1),
#  ('Licht', 1),
#  ('es', 1),
#  ('gestatteten;', 1),
#  ('darüber', 1),
#  ('standen', 1),
#  ('auf', 1),
#  ('festen,', 1),
#  ('hohen', 1),
#  ('Säulen', 1),
#  ('die', 1),
#  ('Gebäude', 1),
#  ('der', 1),
#  ('Menschen,', 1),
#  ('in', 1),
#  ('deren', 1),
#  ('unteren', 1),
#  ('Stockwerken', 1),
#  ('die', 1),
#  ('Industrie', 1),
#  ('ihr', 1),
#  ('geschäftiges', 1),
#  ('Leben', 1),
#  ('trieb.', 1),
#  ('Weiter', 1),
#  ('oben', 1),
#  ('folgten', 1),
#  ('Privatwohnungen,', 1),
#  ('und', 1),
#  ('die', 1),
#  ('Krone', 1),
#  ('des', 1),
#  ('Ganzen', 1),
#  ('bildeten', 1),
#  ('anmutige', 1),
#  ('Gärten,', 1),
#  ('deren', 1),
#  ('freie', 1),
#  ('und', 1),
#  ('gesunde', 1),
#  ('Lage', 1),
#  ('sie', 1),
#  ('zum', 1),
#  ('beliebtesten', 1),
#  ('Aufenthalte', 1),
#  ('machte.', 1),
#  ('', 1),
#  ('Die', 1),
#  ('Aufeinanderfolge', 1),
#  ('von', 1),
#  ('fünfzehn', 1),
#  ('bis', 1),
#  ('fünfundzwanzig', 1),
#  ('Stockwerken', 1),
#  ('war', 1),
#  ('übrigens', 1),
#  ('durchaus', 1),
#  ('nicht', 1),
#  ('mit', 1),
#  ('Unbequemlichkeiten', 1),
#  ('verbunden;', 1),
#  ('denn', 1),
#  ('der', 1),
#  ('Luftwagen', 1),
#  ('war', 1),
#  ('das', 1),
#  ('gewöhnliche', 1),
#  ('Verkehrsmittel;', 1),
#  ('und', 1),
#  ('wollte', 1),
#  ('man', 1),
#  ('wirklich', 1),
#  ('einmal', 1),
#  ('zu', 1),
#  ('Fuß', 1),
#  ('ausgehen,', 1),
#  ('so', 1),
#  ('fanden', 1),
#  ('sich', 1),
#  ('die', 1),
#  ('Treppen', 1),
#  ('durch', 1),
#  ('treffliche', 1),
#  ('Hebe', 1),
#  ('—', 1),
#  ('und', 1),
#  ('Senkvorrichtungen', 1),
#  ('ersetzt.', 1),
#  ('In', 1),
#  ('den', 1),
#  ('Städten', 1),
#  ('–', 1),
#  ('und', 1),
#  ('deren', 1),
#  ('gab', 1),
#  ('es', 1),
#  ('unzählige', 1),
#  ('–', 1),
#  ('waren', 1),
#  ('außerdem', 1),
#  ('die', 1),
#  ('einzelnen', 1),
#  ('Stockwerke', 1),
#  ('längs', 1),
#  ('der', 1),
#  ('Straßenfront', 1),
#  ('durch', 1),
#  ('Galerien', 1),
#  ('verbunden;', 1),
#  ('ihre', 1),
#  ('Benutzung', 1),
#  ('war', 1),
#  ('bequem', 1),
#  ('und', 1),
#  ('praktisch,', 1),
#  ('aber', 1),
#  ('–', 1),
#  ('wie', 1),
#  ('es', 1),
#  ('so', 1),
#  ('geht,', 1),
#  ('man', 1),
#  ('weiß', 1),
#  ('nicht', 1),
#  ('immer,', 1),
#  ('warum', 1),
#  ('–', 1),
#  ('bei', 1),
#  ('der', 1),
#  ('feinen', 1),
#  ('Gesellschaft', 1),
#  ('galt', 1),
#  ('sie', 1),
#  ('nicht', 1),
#  ('für', 1),
#  ('standesgemäß;', 1),
#  ('sie', 1),
#  ('diente', 1),
#  ('nur', 1),
#  ('dem', 1),
#  ('kleinen', 1),
#  ('Geschäftsverkehr', 1),
#  ('und', 1),
#  ('Hausgebrauche.', 1),
#  ('Ebenso', 1),
#  ('hielt', 1),
#  ('man', 1),
#  ('es', 1),
#  ('für', 1),
#  ('unpassend,', 1),
#  ('ja,', 1),
#  ('es', 1),
#  ('war', 1),
#  ('sogar', 1),
#  ('straßenpolizeilich', 1),
#  ('verboten,', 1),
#  ('innerhalb', 1),
#  ('der', 1),
#  ('Stadt', 1),
#  ('mit', 1),
#  ('den', 1),
#  ('leichten', 1),
#  ('Fahrzeugen', 1),
#  ('sich', 1),
#  ('höher', 1),
#  ('als', 1),
#  ('die', 1),
#  ('Dächer', 1),
#  ('der', 1),
#  ('Häuser', 1),
#  ('zu', 1),
#  ('erheben', 1),
#  ('oder', 1),
#  ('quer', 1),
#  ('über', 1),
#  ('Privatbesitz', 1),
#  ('durch', 1),
#  ('die', 1),
#  ('Luft', 1),
#  ('zu', 1),
#  ('fliegen.', 1),
#  ('Natürlich', 1),
#  ('gab', 1),
#  ('es', 1),
#  ('auch', 1),
#  ('immer', 1),
#  ('mutwillige', 1),
#  ('und', 1),
#  ('unartige', 1),
#  ('Übertreter', 1),
#  ('dieser', 1),
#  ('Sitte,', 1),
#  ('und', 1),
#  ('wenn', 1),
#  ('es', 1),
#  ('früher,', 1),
#  ('im', 1),
#  ('rohen', 1),
#  ('Neu-Mittelalter,', 1),
#  ('der', 1),
#  ('Übermut', 1),
#  ('der', 1),
#  ('männlichen', 1),
#  ('Jugend', 1),
#  ('nicht', 1),
#  ('verschmähte,', 1),
#  ('in', 1),
#  ('weinseliger', 1),
#  ('Nacht', 1),
#  ('allerlei', 1),
#  ('Unfug', 1),
#  ('an', 1),
#  ('Schildern', 1),
#  ('und', 1),
#  ('Hausklingeln', 1),
#  ('zu', 1),
#  ('verüben,', 1),
#  ('so', 1),
#  ('kam', 1),
#  ('es', 1),
#  ('auch', 1),
#  ('heute', 1),
#  ('wohl', 1),
#  ('vor,', 1),
#  ('daß', 1),
#  ('sich', 1),
#  ('am', 1),
#  ('Morgen', 1),
#  ('ein', 1),
#  ('Fenster', 1),
#  ('mit', 1),
#  ('schönen', 1),
#  ('Bildern', 1),
#  ('verklebt', 1),
#  ('fand', 1),
#  ('oder', 1),
#  ('ein', 1),
#  ('wohlverpacktes', 1),
#  ('Bukett', 1),
#  ('zum', 1),
#  ('Schornstein', 1),
#  ('hereinspazierte.', 1),
#  ('', 1),
#  ('Aromasia', 1),
#  ('Duftemann', 1),
#  ('Ozodes,', 1),
#  ('die', 1),
#  ('allverehrte', 1),
#  ('Künstlerin,', 1),
#  ('seufzte', 1),
#  ('leise,', 1),
#  ('nachdem', 1),
#  ('sie', 1),
#  ('wieder', 1),
#  ('vergebens', 1),
#  ('in', 1),
#  ('der', 1),
#  ('Menge', 1),
#  ('der', 1),
#  ('Luft-Droschken', 1),
#  ('nach', 1),
#  ('dem', 1),
#  ('Ziele', 1),
#  ('ihrer', 1),
#  ('Sehnsucht', 1),
#  ('gesucht', 1),
#  ('hatte.', 1),
#  ('', 1),
#  ('»Wo', 1),
#  ('nur', 1),
#  ('Oxygen', 1),
#  ('bleiben', 1),
#  ('mag?«', 1),
#  ('klagte', 1),
#  ('sie', 1),
#  ('sanft', 1),
#  ('in', 1),
#  ('den', 1),
#  ('wohltönenden', 1),
#  ('Lauten', 1),
#  ('der', 1),
#  ('deutschen', 1),
#  ('Sprache.', 1),
#  ('Denn', 1),
#  ('wenn', 1),
#  ('man', 1),
#  ('auch', 1),
#  ('im', 1),
#  ('gewöhnlichen', 1),
#  ('Verkehre', 1),
#  ('sich', 1),
#  ('fast', 1),
#  ('ausschließlich', 1),
#  ('der', 1),
#  ('neu', 1),
#  ('eingeführten', 1),
#  ('Universalsprache', 1),
#  ('zu', 1),
#  ('bedienen', 1),
#  ('pflegte,', 1),
#  ('so', 1),
#  ('sprach', 1),
#  ('man', 1),
#  ('doch', 1),
#  ('die', 1),
#  ('zarten', 1),
#  ('Empfindungen', 1),
#  ('des', 1),
#  ('Herzens', 1),
#  ('in', 1),
#  ('den', 1),
#  ('süßen', 1),
#  ('Klängen', 1),
#  ('der', 1),
#  ('ursprünglichen', 1),
#  ('Muttersprache', 1),
#  ('aus.', 1),
#  ('', 1),
#  ('»Merkwürdig«,', 1),
#  ('fuhr', 1),
#  ('sie', 1),
#  ('fort,', 1),
#  ('»daß', 1),
#  ('er', 1),
#  ('nicht', 1),
#  ('nach', 1),
#  ('seiner', 1),
#  ('Gewohnheit', 1),
#  ('längst', 1),
#  ('zu', 1),
#  ('mir', 1),
#  ('geeilt.', 1),
#  ('Schon', 1),
#  ('neun', 1),
#  ('Uhr', 1),
#  ('vierundachtzig', 1),
#  ('Minuten', 1),
#  ('siebzig', 1),
#  ('Sekunden?', 1),
#  ('Und', 1),
#  ('auch', 1),
#  ('Magnet', 1),
#  ('kommt', 1),
#  ('nicht', 1),
#  ('–', 1),
#  ('aber', 1),
#  ('die', 1),
#  ('Dichter', 1),
#  ('sind', 1),
#  ('unpünktlich.', 1),
#  ('Er', 1),
#  ('sinnt', 1),
#  ('gewiß', 1),
#  ('auf', 1),
#  ('ein', 1),
#  ('Grunzulett;', 1),
#  ('und', 1),
#  ('dazu', 1),
#  ('braucht', 1),
#  ('er', 1),
#  ('Zeit.«', 1),
#  ('', 1),
#  ('Das', 1),
#  ('Grunzulett', 1),
#  ('ist', 1),
#  ('nämlich', 1),
#  ('eine', 1),
#  ('neue', 1),
#  ('Dichtungsform,', 1),
#  ('welche', 1),
#  ('die', 1),
#  ('Vorzüge', 1),
#  ('des', 1),
#  ('Sonetts,', 1),
#  ('des', 1),
#  ('Gasels,', 1),
#  ('der', 1),
#  ('alcäischen', 1),
#  ('Strophe', 1),
#  ('und', 1),
#  ('des', 1),
#  ('Familienromans', 1),
#  ('in', 1),
#  ('sich', 1),
#  ('vereinigt,', 1),
#  ('leider', 1),
#  ('aber', 1),
#  ('nur', 1),
#  ('in', 1),
#  ('der', 1),
#  ('modernen', 1),
#  ('Universalsprache', 1),
#  ('zu', 1),
#  ('leisten', 1),
#  ('ist,', 1),
#  ('weil', 1),
#  ('seine', 1),
#  ('Hauptschönheit', 1),
#  ('darin', 1),
#  ('besteht,', 1),
#  ('daß', 1),
#  ('Alliteration', 1),
#  ('und', 1),
#  ('Reim', 1),
#  ('durch', 1),
#  ('eigene', 1),
#  ('Selbstvernichtung', 1),
#  ('sich', 1),
#  ('zu', 1),
#  ('einer', 1),
#  ('neuen', 1),
#  ('Form,', 1),
#  ('der', 1),
#  ('»in', 1),
#  ('sich', 1),
#  ('zurückkehrenden', 1),
#  ('unendlichen', 1),
#  ('Lautquetsche«,', 1),
#  ('verbinden.', 1),
#  ('', 1),
#  ('Jetzt', 1),
#  ('griff', 1),
#  ('Aromasia', 1),
#  ('nach', 1),
#  ('dem', 1),
#  ('neben', 1),
#  ('ihr', 1),
#  ('liegenden', 1),
#  ('Doppelfernrohr', 1),
#  ('und', 1),
#  ('sah', 1),
#  ('scharf', 1),
#  ('nach', 1),
#  ('einer', 1),
#  ('Stelle', 1),
#  ('der', 1),
#  ('Vorstadt,', 1),
#  ('welche', 1),
#  ('ungefähr', 1),
#  ('25', 1),
#  ('Kilometer', 1),
#  ('von', 1),
#  ('ihrem', 1),
#  ('Standpunkte', 1),
#  ('entfernt', 1),
#  ('sein', 1),
#  ('mochte;', 1),
#  ('eine', 1),
#  ('jener', 1),
#  ('schon', 1),
#  ('erwähnten', 1),
#  ('kleinen', 1),
#  ('Wolken', 1),
#  ('erhob', 1),
#  ('sich', 1),
#  ('gerade', 1),
#  ('darüber.', 1),
#  ('', 1),
#  ('»Es', 1),
#  ('ist', 1),
#  ('Oxygen«,', 1),
#  ('sagte', 1),
#  ('sie', 1),
#  ('beruhigt', 1),
#  ('bei', 1),
#  ('sich,', 1),
#  ('indem', 1),
#  ('sie', 1),
#  ('das', 1),
#  ('Fernrohr', 1),
#  ('sinken', 1),
#  ('ließ.', 1),
#  ('»Ich', 1),
#  ('erkenne', 1),
#  ('seine', 1),
#  ('Maschine.', 1),
#  ('Er', 1),
#  ('ist', 1),
#  ('also', 1),
#  ('beschäftigt', 1),
#  ('und', 1),
#  ('wird', 1),
#  ('erst', 1),
#  ('später', 1),
#  ('erscheinen.', 1),
#  ('So', 1),
#  ('muß', 1),
#  ('ich', 1),
#  ('mir', 1),
#  ('denn', 1),
#  ('bis', 1),
#  ('zu', 1),
#  ('seiner', 1),
#  ('Ankunft', 1),
#  ('die', 1),
#  ('Zeit', 1),
#  ('nach', 1),
#  ('eigenem', 1),
#  ('Geschmack', 1),
#  ('vertreiben.', 1),
#  ('Wohlauf,', 1),
#  ('meine', 1),
#  ('getreue', 1),
#  ('Kunst!', 1),
#  ('Ihr', 1),
#  ('gewaltigen', 1),
#  ('Gedanken', 1),
#  ('der', 1),
#  ('großen', 1),
#  ('Duftmeister', 1),
#  ('sollt', 1),
#  ('mir', 1),
#  ('die', 1),
#  ('schleichende', 1),
#  ('Stunde', 1),
#  ('verkürzen', 1),
#  ('und', 1),
#  ('meine', 1),
#  ('Seele', 1),
#  ('in', 1),
#  ('die', 1),
#  ('Regionen', 1),
#  ('wunschlosen', 1),
#  ('Wahnes', 1),
#  ('tragen!«', 1),
#  ('', 1),
#  ('Sie', 1),
#  ('trat', 1),
#  ('auf', 1),
#  ('die', 1),
#  ('Versenkung', 1),
#  ('und', 1),
#  ('befand', 1),
#  ('sich', 1),
#  ('wenige', 1),
#  ('Augenblicke', 1),
#  ('später', 1),
#  ('in', 1),
#  ('ihrem', 1),
#  ('geschmackvoll', 1),
#  ('eingerichteten', 1),
#  ('Zimmer.', 1),
#  ('Ein', 1),
#  ('Instrument', 1),
#  ('in', 1),
#  ('der', 1),
#  ('Gestalt', 1),
#  ('eines', 1),
#  ('Pianinos', 1),
#  ('stand', 1),
#  ('in', 1),
#  ('der', 1),
#  ('Mitte.', 1),
#  ('Sie', 1),
#  ('öffnete', 1),
#  ('den', 1),
#  ('Deckel', 1),
#  ('und', 1),
#  ('griff', 1),
#  ('in', 1),
#  ('die', 1),
#  ('Klaviatur', 1),
#  ('des', 1),
#  ('Ododions;', 1),
#  ('bald', 1),
#  ('schwelgte', 1),
#  ('sie', 1),
#  ('in', 1),
#  ('den', 1),
#  ('Wonnedüften', 1),
#  ('einer', 1),
#  ('Phantasie', 1),
#  ('von', 1),
#  ('Riechmann,', 1),
#  ('und', 1),
#  ('harmonische', 1),
#  ('Wohlgerüche', 1),
#  ('durchströmten', 1),
#  ('das', 1),
#  ('Zimmer.', 1),
#  ('', 1),
#  ('Das', 1),
#  ('Ododion', 1),
#  ('oder', 1),
#  ('Geruchsklavier', 1),
#  ('wurde', 1),
#  ('im', 1),
#  ('Jahre', 1),
#  ('2094', 1),
#  ('von', 1),
#  ('einem', 1),
#  ('Italiener', 1),
#  ('Namens', 1),
#  ('Odorato', 1),
#  ('erfunden', 1),
#  ('und', 1),
#  ('im', 1),
#  ('Laufe', 1),
#  ('der', 1),
#  ('Zeit,', 1),
#  ('entsprechend', 1),
#  ('den', 1),
#  ('Fortschritten', 1),
#  ('der', 1),
#  ('Chemie,', 1),
#  ('bedeutend', 1),
#  ('vervollkommnet.', 1),
#  ('Das', 1),
#  ('Instrument', 1),
#  ('unserer', 1),
#  ('Künsterlin', 1),
#  ('war', 1),
#  ('aus', 1),
#  ('einer', 1),
#  ('deutschen', 1),
#  ('Fabrik', 1),
#  ('und', 1),
#  ('zeichnete', 1),
#  ('sich', 1),
#  ('durch', 1),
#  ('seinen', 1),
#  ('großen', 1),
#  ('Umfang', 1),
#  ('an', 1),
#  ('Gerüchen', 1),
#  ('aus;', 1),
#  ('es', 1),
#  ('reichte', 1),
#  ('von', 1),
#  ('dem', 1),
#  ('als', 1),
#  ('unterste', 1),
#  ('Duftstufe', 1),
#  ('angenommenen', 1),
#  ('dumpfen', 1),
#  ('Keller', 1),
#  ('—', 1),
#  ('und', 1),
#  ('Modergeruche', 1),
#  ('bis', 1),
#  ('zum', 1),
#  ('Zwiblozin,', 1),
#  ('einem', 1),
#  ('erst', 1),
#  ('im', 1),
#  ('Jahre', 1),
#  ('2369', 1),
#  ('entdeckten', 1),
#  ('äußerst', 1),
#  ('zarten', 1),
#  ('Odeur.', 1),
#  ('Jeder', 1),
#  ('Druck', 1),
#  ('auf', 1),
#  ('eine', 1),
#  ('Taste', 1),
#  ('öffnete', 1),
#  ('einen', 1),
#  ('entsprechenden', 1),
#  ('Gasometer,', 1),
#  ('und', 1),
#  ('künstliche', 1),
#  ('mechanische', 1),
#  ('Vorrichtungen', 1),
#  ('sorgten', 1),
#  ('für', 1),
#  ('die', 1),
#  ('Dämpfung,', 1),
#  ('Ausbreitung', 1),
#  ('und', 1),
#  ('Zusammenwirkung', 1),
#  ('der', 1),
#  ('Düfte.', 1),
#  ('', 1),
#  ('Nachdem', 1),
#  ('man', 1),
#  ('die', 1),
#  ('Musik', 1),
#  ('auf', 1),
#  ('einen', 1),
#  ('solchen', 1),
#  ('Höhepunkt', 1),
#  ('der', 1),
#  ('Vervollkommnung', 1),
#  ('gebracht', 1),
#  ('hatte,', 1),
#  ('daß', 1),
#  ('das', 1),
#  ('Ohr', 1),
#  ('unmöglich', 1),
#  ('mehr', 1),
#  ('ertragen', 1),
#  ('konnte,', 1),
#  ('hatte', 1),
#  ('man', 1),
#  ('seine', 1),
#  ('Aufmerksamkeit', 1),
#  ('der', 1),
#  ('so', 1),
#  ('sehr', 1),
#  ('vernachlässigten', 1),
#  ('Nase', 1),
#  ('zugewandt.', 1),
#  ('Die', 1),
#  ('Feinheit', 1),
#  ('des', 1),
#  ('Geruchsorgans', 1),
#  ('war', 1),
#  ('freilich', 1),
#  ('bei', 1),
#  ('der', 1),
#  ('Menschheit', 1),
#  ('in', 1),
#  ('der', 1),
#  ('Rückbildung', 1),
#  ('begriffen;', 1),
#  ('aber', 1),
#  ('warum', 1),
#  ('sollte', 1),
#  ('man', 1),
#  ('diese', 1),
#  ('nicht', 1),
#  ('steuern', 1),
#  ('können?', 1),
#  ('Kein', 1),
#  ('anderer', 1),
#  ('Sinn', 1),
#  ('wirkt', 1),
#  ('gleich', 1),
#  ('lebhaft', 1),
#  ('auf', 1),
#  ('unsere', 1),
#  ('Ideenassoziation', 1),
#  ('wie', 1),
#  ('der', 1),
#  ('des', 1),
#  ('Geruchs;', 1),
#  ('es', 1),
#  ('lag', 1),
#  ('nahe,', 1),
#  ('ihn', 1),
#  ('künstlerisch', 1),
#  ('dazu', 1),
#  ('zu', 1),
#  ('verwerten,', 1),
#  ('bestimmte', 1),
#  ('Vorstellungen', 1),
#  ('und', 1),
#  ('Empfindungen', 1),
#  ('in', 1),
#  ('uns', 1),
#  ('hervorzurufen.', 1),
#  ('Man', 1),
#  ('studierte', 1),
#  ('die', 1),
#  ('Eigentümlichkeiten', 1),
#  ('und', 1),
#  ('Wirkungen', 1),
#  ('der', 1),
#  ('Gerüche,', 1),
#  ('fand', 1),
#  ('die', 1),
#  ('Gesetze', 1),
#  ('ihrer', 1),
#  ('Harmonie', 1),
#  ('und', 1),
#  ('Disharmonie,', 1),
#  ('anfänglich', 1),
#  ('auf', 1),
#  ('empirischem,', 1),
#  ('später', 1),
#  ('auch', 1),
#  ('auf', 1),
#  ('theoretischem', 1),
#  ('Wege,', 1),
#  ('die', 1),
#  ('Chemie', 1),
#  ('stellte', 1),
#  ('immer', 1),
#  ('wohlfeiler', 1),
#  ('die', 1),
#  ('notwendigen', 1),
#  ('Aromen', 1),
#  ('her,', 1),
#  ('und', 1),
#  ('nachdem', 1),
#  ('das', 1),
#  ('Ododion', 1),
#  ('erst', 1),
#  ('als', 1),
#  ('Kuriosum', 1),
#  ('gezeigt', 1),
#  ('und', 1),
#  ('auf', 1),
#  ('Rundreisen', 1),
#  ('durch', 1),
#  ('die', 1),
#  ('Städte', 1),
#  ('von', 1),
#  ('aller', 1),
#  ('Welt', 1),
#  ('angestaunt', 1),
#  ('worden', 1),
#  ('war,', 1),
#  ('bürgerte', 1),
#  ('es', 1),
#  ('sich', 1),
#  ('bald', 1),
#  ('in', 1),
#  ('den', 1),
#  ('Familien,', 1),
#  ('im', 1),
#  ('Privatkreise', 1),
#  ('ein.', 1),
#  ('', 1),
#  ('Die', 1),
#  ('größten', 1),
#  ('Duftmeister,', 1),
#  ('zuerst', 1),
#  ('Naso', 1),
#  ('Odorato,', 1),
#  ('dann', 1),
#  ('Stinkerling,', 1),
#  ...]

# %%
text_flat=in_text.flatMap(lambda x: x.split(' '))\
                 .map(lambda x: (x,1))\
                 .reduceByKey(lambda x,y : x+y)

# %%
text_flat.collect()
# Out:
# [('Kurd', 1),
#  ('Laßwitz', 1),
#  ('', 280),
#  ('Bis', 3),
#  ('zum', 16),
#  ('Nullpunkt', 4),
#  ('des', 124),
#  ('Seins', 7),
#  ('Erzählung', 1),
#  ('aus', 34),
#  ('dem', 74),
#  ('Jahre', 6),
#  ('2371', 1),
#  ('Das', 24),
#  ('Geruchsklavier', 4),
#  ('Aromasia', 44),
#  ('saß', 3),
#  ('im', 57),
#  ('Garten', 2),
#  ('ihres', 4),
#  ('Hauses', 2),
#  ('und', 315),
#  ('sah', 5),
#  ('träumerisch', 1),
#  ('ins', 8),
#  ('Blau', 1),
#  ('schönen', 5),
#  ('Sommertages', 1),
#  ('vom', 10),
#  ('2371.', 2),
#  ('Sie', 37),
#  ('folgte', 3),
#  ('mit', 73),
#  ('ihren', 16),
#  ('Blicken', 1),
#  ('den', 181),
#  ('kleinen', 8),
#  ('dunklen', 2),
#  ('Wolken,', 1),
#  ('welche', 47),
#  ('sich', 123),
#  ('hier', 11),
#  ('da', 8),
#  ('plötzlich', 4),
#  ('in', 205),
#  ('der', 394),
#  ('Atmosphäre', 4),
#  ('bildeten', 2),
#  ('einen', 30),
#  ('Regenguß', 2),
#  ('herabströmen', 1),
#  ('ließen;', 1),
#  ('oder', 22),
#  ('sie', 86),
#  ('spähte', 1),
#  ('nach', 31),
#  ('fliegenden', 1),
#  ('Wagen', 3),
#  ('Luftvelozipeden', 1),
#  ('aus,', 2),
#  ('die', 372),
#  ('zu', 165),
#  ('Füßen', 5),
#  ('buntem', 1),
#  ('Gewühle', 1),
#  ('breite', 1),
#  ('Straße', 1),
#  ('erfüllten.', 1),
#  ('Denn', 9),
#  ('Aromasias', 14),
#  ('befand', 3),
#  ('luftigen', 1),
#  ('Höhe', 3),
#  ('von', 91),
#  ('ungefähr', 2),
#  ('hundert', 1),
#  ('Metern', 1),
#  ('über', 32),
#  ('Erdboden', 1),
#  ('auf', 79),
#  ('Dache', 2),
#  ('Hauses.', 1),
#  ('Man', 5),
#  ('genötigt,', 1),
#  ('Wohnhäuser', 1),
#  ('so', 77),
#  ('gewaltigen', 2),
#  ('Dimensionen', 1),
#  ('aufzutürmen', 1),
#  ('Gärten', 1),
#  ('ihnen', 8),
#  ('anzubringen,', 1),
#  ('man', 44),
#  ('Raum', 7),
#  ('ebenen', 1),
#  ('Erde', 14),
#  ('Ackerbau', 1),
#  ('vorbehalten', 1),
#  ('mußte.', 2),
#  ('So', 13),
#  ('reichbevölkert', 1),
#  ('war', 68),
#  ('Erdball,', 1),
#  ('daß', 87),
#  ('jedes', 5),
#  ('Plätzchen', 3),
#  ('Anbau', 1),
#  ('Halmfrucht', 1),
#  ('Ernährung', 1),
#  ('Schlachtviehs', 1),
#  ('widmen', 1),
#  ('mußte,', 1),
#  ('um', 28),
#  ('Gefahr', 3),
#  ('einer', 41),
#  ('Hungersnot', 1),
#  ('abzuwenden.', 1),
#  ('wogten', 1),
#  ('denn', 12),
#  ('am', 13),
#  ('Boden', 1),
#  ('Getreidefelder,', 1),
#  ('wo', 8),
#  ('immer', 14),
#  ('Luft', 7),
#  ('Licht', 2),
#  ('es', 95),
#  ('gestatteten;', 1),
#  ('darüber', 1),
#  ('standen', 3),
#  ('festen,', 1),
#  ('hohen', 2),
#  ('Säulen', 1),
#  ('Gebäude', 7),
#  ('Menschen,', 1),
#  ('deren', 8),
#  ('unteren', 1),
#  ('Stockwerken', 2),
#  ('Industrie', 2),
#  ('ihr', 31),
#  ('geschäftiges', 1),
#  ('Leben', 10),
#  ('trieb.', 1),
#  ('Weiter', 1),
#  ('oben', 3),
#  ('folgten', 1),
#  ('Privatwohnungen,', 1),
#  ('Krone', 1),
#  ('Ganzen', 2),
#  ('anmutige', 1),
#  ('Gärten,', 1),
#  ('freie', 1),
#  ('gesunde', 1),
#  ('Lage', 2),
#  ('beliebtesten', 1),
#  ('Aufenthalte', 1),
#  ('machte.', 2),
#  ('Die', 38),
#  ('Aufeinanderfolge', 1),
#  ('fünfzehn', 1),
#  ('bis', 13),
#  ('fünfundzwanzig', 1),
#  ('übrigens', 2),
#  ('durchaus', 2),
#  ('nicht', 127),
#  ('Unbequemlichkeiten', 1),
#  ('verbunden;', 2),
#  ('Luftwagen', 3),
#  ('das', 119),
#  ('gewöhnliche', 2),
#  ('Verkehrsmittel;', 1),
#  ('wollte', 9),
#  ('wirklich', 8),
#  ('einmal', 11),
#  ('Fuß', 1),
#  ('ausgehen,', 1),
#  ('fanden', 2),
#  ('Treppen', 1),
#  ('durch', 68),
#  ('treffliche', 1),
#  ('Hebe', 2),
#  ('—', 11),
#  ('Senkvorrichtungen', 1),
#  ('ersetzt.', 1),
#  ('In', 8),
#  ('Städten', 1),
#  ('–', 73),
#  ('gab', 6),
#  ('unzählige', 1),
#  ('waren', 15),
#  ('außerdem', 1),
#  ('einzelnen', 4),
#  ('Stockwerke', 1),
#  ('längs', 2),
#  ('Straßenfront', 1),
#  ('Galerien', 1),
#  ('ihre', 19),
#  ('Benutzung', 1),
#  ('bequem', 1),
#  ('praktisch,', 1),
#  ('aber', 40),
#  ('wie', 56),
#  ('geht,', 1),
#  ('weiß', 4),
#  ('immer,', 1),
#  ('warum', 4),
#  ('bei', 17),
#  ('feinen', 2),
#  ('Gesellschaft', 7),
#  ('galt', 4),
#  ('für', 35),
#  ('standesgemäß;', 1),
#  ('diente', 1),
#  ('nur', 55),
#  ('Geschäftsverkehr', 1),
#  ('Hausgebrauche.', 1),
#  ('Ebenso', 1),
#  ('hielt', 3),
#  ('unpassend,', 1),
#  ('ja,', 3),
#  ('sogar', 2),
#  ('straßenpolizeilich', 1),
#  ('verboten,', 1),
#  ('innerhalb', 2),
#  ('Stadt', 4),
#  ('leichten', 2),
#  ('Fahrzeugen', 1),
#  ('höher', 2),
#  ('als', 42),
#  ('Dächer', 1),
#  ('Häuser', 1),
#  ('erheben', 3),
#  ('quer', 1),
#  ('Privatbesitz', 1),
#  ('fliegen.', 1),
#  ('Natürlich', 2),
#  ('auch', 41),
#  ('mutwillige', 1),
#  ('unartige', 1),
#  ('Übertreter', 1),
#  ('dieser', 15),
#  ('Sitte,', 2),
#  ('wenn', 26),
#  ('früher,', 1),
#  ('rohen', 1),
#  ('Neu-Mittelalter,', 1),
#  ('Übermut', 1),
#  ('männlichen', 1),
#  ('Jugend', 1),
#  ('verschmähte,', 1),
#  ('weinseliger', 1),
#  ('Nacht', 4),
#  ('allerlei', 1),
#  ('Unfug', 1),
#  ('an', 58),
#  ('Schildern', 1),
#  ('Hausklingeln', 1),
#  ('verüben,', 1),
#  ('kam', 3),
#  ('heute', 4),
#  ('wohl', 4),
#  ('vor,', 5),
#  ('Morgen', 2),
#  ('ein', 96),
#  ('Fenster', 6),
#  ('Bildern', 1),
#  ('verklebt', 1),
#  ('fand', 3),
#  ('wohlverpacktes', 1),
#  ('Bukett', 1),
#  ('Schornstein', 1),
#  ('hereinspazierte.', 1),
#  ('Duftemann', 5),
#  ('Ozodes,', 2),
#  ('allverehrte', 1),
#  ('Künstlerin,', 2),
#  ('seufzte', 1),
#  ('leise,', 1),
#  ('nachdem', 4),
#  ('wieder', 11),
#  ('vergebens', 3),
#  ('Menge', 3),
#  ('Luft-Droschken', 1),
#  ('Ziele', 1),
#  ('ihrer', 16),
#  ('Sehnsucht', 2),
#  ('gesucht', 1),
#  ('hatte.', 7),
#  ('»Wo', 2),
#  ('Oxygen', 34),
#  ('bleiben', 1),
#  ('mag?«', 1),
#  ('klagte', 2),
#  ('sanft', 1),
#  ('wohltönenden', 1),
#  ('Lauten', 1),
#  ('deutschen', 3),
#  ('Sprache.', 1),
#  ('gewöhnlichen', 1),
#  ('Verkehre', 1),
#  ('fast', 3),
#  ('ausschließlich', 2),
#  ('neu', 1),
#  ('eingeführten', 1),
#  ('Universalsprache', 2),
#  ('bedienen', 1),
#  ('pflegte,', 1),
#  ('sprach', 3),
#  ('doch', 26),
#  ('zarten', 4),
#  ('Empfindungen', 4),
#  ('Herzens', 2),
#  ('süßen', 1),
#  ('Klängen', 1),
#  ('ursprünglichen', 2),
#  ('Muttersprache', 1),
#  ('aus.', 2),
#  ('»Merkwürdig«,', 1),
#  ('fuhr', 5),
#  ('fort,', 3),
#  ('»daß', 2),
#  ('er', 92),
#  ('seiner', 28),
#  ('Gewohnheit', 3),
#  ('längst', 1),
#  ('mir', 16),
#  ('geeilt.', 1),
#  ('Schon', 4),
#  ('neun', 2),
#  ('Uhr', 7),
#  ('vierundachtzig', 1),
#  ('Minuten', 3),
#  ('siebzig', 1),
#  ('Sekunden?', 1),
#  ('Und', 28),
#  ('Magnet', 24),
#  ('kommt', 4),
#  ('Dichter', 5),
#  ('sind', 17),
#  ('unpünktlich.', 1),
#  ('Er', 10),
#  ('sinnt', 1),
#  ('gewiß', 5),
#  ('Grunzulett;', 1),
#  ('dazu', 5),
#  ('braucht', 1),
#  ('Zeit.«', 1),
#  ('Grunzulett', 3),
#  ('ist', 59),
#  ('nämlich', 5),
#  ('eine', 60),
#  ('neue', 5),
#  ('Dichtungsform,', 1),
#  ('Vorzüge', 1),
#  ('Sonetts,', 1),
#  ('Gasels,', 1),
#  ('alcäischen', 1),
#  ('Strophe', 1),
#  ('Familienromans', 1),
#  ('vereinigt,', 1),
#  ('leider', 3),
#  ('modernen', 3),
#  ('leisten', 2),
#  ('ist,', 11),
#  ('weil', 3),
#  ('seine', 22),
#  ('Hauptschönheit', 1),
#  ('darin', 1),
#  ('besteht,', 1),
#  ('Alliteration', 1),
#  ('Reim', 1),
#  ('eigene', 5),
#  ('Selbstvernichtung', 2),
#  ('neuen', 5),
#  ('Form,', 2),
#  ('»in', 1),
#  ('zurückkehrenden', 1),
#  ('unendlichen', 3),
#  ('Lautquetsche«,', 1),
#  ('verbinden.', 1),
#  ('Jetzt', 4),
#  ('griff', 2),
#  ('neben', 4),
#  ('liegenden', 1),
#  ('Doppelfernrohr', 1),
#  ('scharf', 2),
#  ('Stelle', 4),
#  ('Vorstadt,', 1),
#  ('25', 1),
#  ('Kilometer', 1),
#  ('ihrem', 7),
#  ('Standpunkte', 3),
#  ('entfernt', 1),
#  ('sein', 16),
#  ('mochte;', 1),
#  ('jener', 5),
#  ('schon', 17),
#  ('erwähnten', 1),
#  ('Wolken', 2),
#  ('erhob', 1),
#  ('gerade', 7),
#  ('darüber.', 1),
#  ('»Es', 5),
#  ('Oxygen«,', 3),
#  ('sagte', 15),
#  ('beruhigt', 1),
#  ('sich,', 3),
#  ('indem', 6),
#  ('Fernrohr', 1),
#  ('sinken', 1),
#  ('ließ.', 1),
#  ('»Ich', 12),
#  ('erkenne', 2),
#  ('Maschine.', 1),
#  ('also', 5),
#  ('beschäftigt', 1),
#  ('wird', 11),
#  ('erst', 9),
#  ('später', 4),
#  ('erscheinen.', 2),
#  ('muß', 14),
#  ('ich', 74),
#  ('Ankunft', 1),
#  ('Zeit', 18),
#  ('eigenem', 1),
#  ('Geschmack', 1),
#  ('vertreiben.', 1),
#  ('Wohlauf,', 1),
#  ('meine', 11),
#  ('getreue', 1),
#  ('Kunst!', 1),
#  ('Ihr', 6),
#  ('Gedanken', 4),
#  ('großen', 15),
#  ('Duftmeister', 1),
#  ('sollt', 1),
#  ('schleichende', 1),
#  ('Stunde', 5),
#  ('verkürzen', 1),
#  ('Seele', 3),
#  ('Regionen', 2),
#  ('wunschlosen', 1),
#  ('Wahnes', 1),
#  ('tragen!«', 1),
#  ('trat', 8),
#  ('Versenkung', 1),
#  ('wenige', 2),
#  ('Augenblicke', 2),
#  ('geschmackvoll', 1),
#  ('eingerichteten', 1),
#  ('Zimmer.', 3),
#  ('Ein', 7),
#  ('Instrument', 2),
#  ('Gestalt', 1),
#  ('eines', 10),
#  ('Pianinos', 1),
#  ('stand', 5),
#  ('Mitte.', 1),
#  ('öffnete', 3),
#  ('Deckel', 1),
#  ('Klaviatur', 1),
#  ('Ododions;', 1),
#  ('bald', 4),
#  ('schwelgte', 1),
#  ('Wonnedüften', 1),
#  ('Phantasie', 1),
#  ('Riechmann,', 2),
#  ('harmonische', 1),
#  ('Wohlgerüche', 2),
#  ('durchströmten', 1),
#  ('Ododion', 9),
#  ('wurde', 10),
#  ('2094', 1),
#  ('einem', 22),
#  ('Italiener', 1),
#  ('Namens', 1),
#  ('Odorato', 1),
#  ('erfunden', 2),
#  ('Laufe', 1),
#  ('Zeit,', 4),
#  ('entsprechend', 1),
#  ('Fortschritten', 1),
#  ('Chemie,', 1),
#  ('bedeutend', 1),
#  ('vervollkommnet.', 1),
#  ('unserer', 8),
#  ('Künsterlin', 1),
#  ('Fabrik', 2),
#  ('zeichnete', 1),
#  ('seinen', 17),
#  ('Umfang', 1),
#  ('Gerüchen', 1),
#  ('aus;', 1),
#  ('reichte', 1),
#  ('unterste', 1),
#  ('Duftstufe', 1),
#  ('angenommenen', 1),
#  ('dumpfen', 1),
#  ('Keller', 1),
#  ('Modergeruche', 1),
#  ('Zwiblozin,', 1),
#  ('2369', 1),
#  ('entdeckten', 1),
#  ('äußerst', 1),
#  ('Odeur.', 1),
#  ('Jeder', 1),
#  ('Druck', 3),
#  ('Taste', 2),
#  ('entsprechenden', 1),
#  ('Gasometer,', 1),
#  ('künstliche', 1),
#  ('mechanische', 1),
#  ('Vorrichtungen', 1),
#  ('sorgten', 1),
#  ('Dämpfung,', 1),
#  ('Ausbreitung', 1),
#  ('Zusammenwirkung', 1),
#  ('Düfte.', 1),
#  ('Nachdem', 1),
#  ('Musik', 5),
#  ('solchen', 4),
#  ('Höhepunkt', 1),
#  ('Vervollkommnung', 1),
#  ('gebracht', 1),
#  ('hatte,', 7),
#  ('Ohr', 1),
#  ('unmöglich', 3),
#  ('mehr', 21),
#  ('ertragen', 1),
#  ('konnte,', 5),
#  ('hatte', 33),
#  ('Aufmerksamkeit', 2),
#  ('sehr', 16),
#  ('vernachlässigten', 1),
#  ('Nase', 5),
#  ('zugewandt.', 1),
#  ('Feinheit', 1),
#  ('Geruchsorgans', 1),
#  ('freilich', 3),
#  ('Menschheit', 14),
#  ('Rückbildung', 1),
#  ('begriffen;', 1),
#  ('sollte', 9),
#  ('diese', 21),
#  ('steuern', 1),
#  ('können?', 1),
#  ('Kein', 4),
#  ('anderer', 1),
#  ('Sinn', 1),
#  ('wirkt', 1),
#  ('gleich', 4),
#  ('lebhaft', 2),
#  ('unsere', 16),
#  ('Ideenassoziation', 1),
#  ('Geruchs;', 1),
#  ('lag', 4),
#  ('nahe,', 1),
#  ('ihn', 29),
#  ('künstlerisch', 1),
#  ('verwerten,', 1),
#  ('bestimmte', 2),
#  ('Vorstellungen', 2),
#  ('uns', 22),
#  ('hervorzurufen.', 2),
#  ('studierte', 1),
#  ('Eigentümlichkeiten', 1),
#  ('Wirkungen', 3),
#  ('Gerüche,', 2),
#  ('Gesetze', 5),
#  ('Harmonie', 1),
#  ('Disharmonie,', 1),
#  ('anfänglich', 1),
#  ('empirischem,', 1),
#  ('theoretischem', 1),
#  ('Wege,', 1),
#  ('Chemie', 1),
#  ('stellte', 2),
#  ('wohlfeiler', 1),
#  ('notwendigen', 1),
#  ('Aromen', 1),
#  ('her,', 1),
#  ('Kuriosum', 1),
#  ('gezeigt', 1),
#  ('Rundreisen', 1),
#  ('Städte', 1),
#  ('aller', 4),
#  ('Welt', 16),
#  ('angestaunt', 1),
#  ('worden', 4),
#  ('war,', 15),
#  ('bürgerte', 1),
#  ('Familien,', 1),
#  ('Privatkreise', 1),
#  ('ein.', 4),
#  ('größten', 2),
#  ('Duftmeister,', 1),
#  ('zuerst', 1),
#  ('Naso', 1),
#  ('Odorato,', 1),
#  ('dann', 14),
#  ('Stinkerling,', 1),
#  ('Frau', 2),
#  ('Schnüffler,', 1),
#  ('Eltern', 1),
#  ('selbst,', 3),
#  ('Herr', 3),
#  ('Griechin,', 1),
#  ('leisteten', 1),
#  ('Ododionpiecen,', 1),
#  ('Tonwerken', 1),
#  ('Musiker', 2),
#  ('dreist', 1),
#  ('gestellt', 1),
#  ('werden', 16),
#  ('konnten,', 1),
#  ('Ododion,', 3),
#  ('namentlich', 1),
#  ('Verbindung', 1),
#  ('menschlichen', 3),
#  ('Stimme', 5),
#  ('hinreißend', 1),
#  ('wirkte,', 1),
#  ('allen', 8),
#  ('Häusern', 1),
#  ('eingebürgert', 1),
#  ('vor', 22),
#  ('fünf', 3),
#  ('Jahrhunderten', 1),
#  ('Klavier.', 1),
#  ('Töchter', 2),
#  ('Söhne', 2),
#  ('räucherten', 1),
#  ('Mußestunden', 2),
#  ('darauf', 3),
#  ('herum,', 1),
#  ('Nachbarn', 1),
#  ('klagten', 1),
#  ('jammerten', 1),
#  ('Stümperei,', 1),
#  ('Geruchsüberladung', 1),
#  ('Nasenmarter', 1),
#  ('so,', 1),
#  ('früher', 2),
#  ('Flügelspiel', 1),
#  ('Ohrenquälerei', 1),
#  ('herzog.', 1),
#  ('Ozodes', 1),
#  ('Künstlerin', 2),
#  ('wahren', 2),
#  ('Sinne', 3),
#  ('Worts.', 1),
#  ('Ihre', 5),
#  ('Duftakkorde', 1),
#  ('umstrickten', 1),
#  ('Allgewalt.', 1),
#  ('Springauf,', 1),
#  ('Flieder', 1),
#  ('Rosen', 1),
#  ('führten', 1),
#  ('Träume', 1),
#  ('holde', 1),
#  ('Sommers', 1),
#  ('jungen', 1),
#  ('Liebe;', 1),
#  ('allmählich', 3),
#  ('verschwimmen', 1),
#  ('Düfte,', 1),
#  ('wir', 51),
#  ('glauben', 2),
#  ('verwelkten', 1),
#  ('Blumen', 1),
#  ('stehen,', 1),
#  ('Gemisch', 2),
#  ('Jasmin', 1),
#  ('Schnittlauch', 1),
#  ('durchzieht', 1),
#  ('Gemüt', 2),
#  ('unendlicher', 2),
#  ('Wehmut.', 1),
#  ('nun', 6),
#  ('Ferne,', 1),
#  ('Wehmut', 1),
#  ('hindurch,', 1),
#  ('riechen', 1),
#  ('Hohn,', 1),
#  ('Leichtsinn', 1),
#  ('Treulosen', 1),
#  ('Dufte', 1),
#  ('Weines;', 1),
#  ('umhüllen', 1),
#  ('Alkoholdämpfe', 1),
#  ('da,', 2),
#  ('Aufschrei', 1),
#  ('Entsetzens,', 1),
#  ('Mißgeruch!', 1),
#  ('Pulver', 1),
#  ('es,', 9),
#  ('dunkle', 1),
#  ('Grabesluft', 1),
#  ('...', 2),
#  ('Noch', 4),
#  ('Schmerz', 8),
#  ('Duftakkorde,', 1),
#  ('verduften', 1),
#  ('stiller', 1),
#  ('Resignation', 1),
#  ('ließ', 6),
#  ('Hand', 3),
#  ('sinken.', 1),
#  ('Da', 9),
#  ('fühlte', 1),
#  ('dieselbe', 7),
#  ('ergriffen', 1),
#  ('heißen', 3),
#  ('Küssen', 1),
#  ('bedeckt.', 1),
#  ('Reimert-Oberton', 3),
#  ('unbemerkt', 1),
#  ('herein', 1),
#  ('luftvelozipediert', 1),
#  ('niedergesunken.', 1),
#  ('bebte', 1),
#  ('Nachgefühl', 1),
#  ('Spieles', 1),
#  ('Aromasias.', 1),
#  ('führte', 3),
#  ('alle', 16),
#  ('Leute', 1),
#  ('Doppelnamen.', 1),
#  ('Der', 13),
#  ('rechtlichen', 1),
#  ('Gleichstellung', 1),
#  ('Frauen', 1),
#  ('gemäß', 1),
#  ('behielten', 1),
#  ('Kinder', 1),
#  ('sowohl', 1),
#  ('Namen', 5),
#  ('Mutter', 2),
#  ('Vaters;', 1),
#  ('verheirateten', 1),
#  ('ließen', 2),
#  ('Vaters,', 1),
#  ('fort', 5),
#  ('nahmen', 2),
#  ('dafür', 2),
#  ('Gemahls', 1),
#  ('hinzu.', 1),
#  ('ebenfalls', 2),
#  ('Künstler,', 1),
#  ('zwar', 2),
#  ('Dichter.', 1),
#  ('Nach', 1),
#  ('unseren', 2),
#  ('Begriffen', 1),
#  ('würde', 10),
#  ('unerträglichen', 1),
#  ('Realisten', 1),
#  ('bezeichnen,', 1),
#  ('damaligen', 1),
#  ('Zeialter', 1),
#  ('übermäßiger', 1),
#  ('Idealist,', 1),
#  ('sondern', 4),
#  ('weichlicher', 1),
#  ('Romantiker.', 1),
#  ('noch', 41),
#  ('dreiundzwanzigsten', 1),
#  ('Jahrhunderts,', 2),
#  ('gern', 1),
#  ('Zeitalter', 3),
#  ('Dampfes', 1),
#  ('zurückträumten,', 1),
#  ('jene', 6),
#  ('Tage,', 2),
#  ('Menschen', 14),
#  ('gezwungen', 3),
#  ('waren,', 2),
#  ('Bergen', 1),
#  ('aufzusehen.', 1),
#  ('verzweifelte', 1),
#  ('Macht', 6),
#  ('Poesie', 3),
#  ('Jahrhundert,', 1),
#  ('welchem', 8),
#  ('rechnenden', 1),
#  ('Verstand', 1),
#  ('vergötterte,', 1),
#  ('pries', 1),
#  ('Neumittelalters', 1),
#  ('glücklich,', 1),
#  ('welcher', 13),
#  ('ankam,', 1),
#  ('heiliges', 1),
#  ('Wunder', 1),
#  ('Klopfgeistern', 1),
#  ('verkehren.', 1),
#  ('Eine', 7),
#  ('Neuerung', 1),
#  ('jedoch', 2),
#  ('versucht,', 1),
#  ('Verdienst', 2),
#  ('Literatur', 1),
#  ('bildete,', 1),
#  ('Einführung', 1),
#  ('begrifflich', 1),
#  ('strengen', 1),
#  ('wissenschaftlichen', 2),
#  ('technischen', 1),
#  ('Bezeichnungen', 1),
#  ('Vorgänge', 1),
#  ('veralteten', 1),
#  ('Anschauung', 2),
#  ('beruhenden', 1),
#  ('sogenannten', 2),
#  ('poetischen.', 1),
#  ('Übrigens', 2),
#  ('dichtete', 1),
#  ('meist', 1),
#  ('deutsch', 1),
#  ('verfaßte', 1),
#  ('Grunzuletts', 1),
#  ('Universalsprache.', 1),
#  ('»O', 1),
#  ('große', 4),
#  ('Aromasia«,', 2),
#  ('rief', 12),
#  ('jetzt,', 2),
#  ('»des', 1),
#  ('vierundzwanzigsten', 3),
#  ('Jahrhunderts', 4),
#  ('erhabenste', 1),
#  ('Ododistin!', 1),
#  ('Ihnen', 6),
#  ('gehört', 1),
#  ('Schwingungszustand', 1),
#  ('meiner', 7),
#  ('Gehirnzellen,', 1),
#  ('bebt', 1),
#  ('jede', 7),
#  ('Nervenfaser', 1),
#  ('meines', 2),
#  ('Rückenmarks!', 1),
#  ('Wie', 9),
#  ('Flur', 1),
#  ('Wasserdämpfen', 1),
#  ('gesättigte', 1),
#  ('Morgenluft', 1),
#  ('stark', 1),
#  ('absorbierten', 1),
#  ('Sonnenstrahlen', 1),
#  ('entgegenseufzt,', 1),
#  ('zittern', 1),
#  ('Düften', 2),
#  ('Ihres', 1),
#  ('Ododions', 1),
#  ('Häute', 1),
#  ('Nase!«', 1),
#  ('»Magnet«,', 1),
#  ('erwiderte', 5),
#  ('Aromasia,', 7),
#  ('Finger', 2),
#  ('drohend,', 1),
#  ('»seien', 1),
#  ('unartig!', 1),
#  ('vergessen', 2),
#  ('wieder,', 1),
#  ('was', 21),
#  ('ausgemacht', 1),
#  ('haben', 11),
#  ('Anbetung', 2),
#  ('gestattet,', 1),
#  ('geziemenden', 1),
#  ('Grenzen.', 1),
#  ('verdienten', 2),
#  ('wirklich,', 1),
#  ('mein', 4),
#  ('Bräutigam', 3),
#  ('Hals', 1),
#  ('schickte.', 1),
#  ('Ich', 22),
#  ('will', 5),
#  ('darum', 3),
#  ('bitten!«', 1),
#  ('»Grausame!', 1),
#  ('fürchte', 2),
#  ('keine', 10),
#  ('Kondensation', 1),
#  ('lebendige', 2),
#  ('Kraft', 6),
#  ('Blutes', 1),
#  ('Wassermolekel', 1),
#  ('auseinandertreiben.«', 1),
#  ('»Warten', 1),
#  ('ab!', 1),
#  ('wissen', 2),
#  ('übertreiben.', 1),
#  ('Schmeicheleien', 1),
#  ('müssen', 8),
#  ('Spott', 1),
#  ('klingen,', 1),
#  ('kenne', 2),
#  ('gut', 5),
#  ('schwachen', 1),
#  ('Kräfte,', 1),
#  ('Ideale', 4),
#  ('erreichen.', 1),
#  ('Wo', 3),
#  ('bleibt', 4),
#  ('Gedankentiefe', 1),
#  ('Riechmann', 1),
#  ('meinem', 5),
#  ('Gedüftel.', 1),
#  ('Riechen', 1),
#  ('diesen', 10),
#  ('einfachen', 2),
#  ('Übergang', 1),
#  ('aromatischen', 1),
#  ('Drei-Duft', 1),
#  ('halben', 1),
#  ('Mollgeruch', 1),
#  ('Schlußozodie.', 1),
#  ('Was', 11),
#  ('liegt', 2),
#  ('alles', 7),
#  ('diesem', 10),
#  ('Zuge!', 1),
#  ('Kraft,', 2),
#  ('Todesmut,', 1),
#  ('Stärke,', 1),
#  ('Stiergebrüll,', 1),
#  ('ganze', 8),
#  ('Geschichte', 2),
#  ('Erfindung', 2),
#  ('elektromotorischen', 1),
#  ('Schnellwagens,', 1),
#  ('Menschengröße,', 1),
#  ('Gewitter,', 1),
#  ('Winzertanz', 1),
#  ('Elemente', 1),
#  ('Kometenbahn', 1),
#  ('neunzehnhundertachtzig.', 1),
#  ('kann', 17),
#  ('Richard', 1),
#  ('Riechmann.«', 1),
#  ('»Sie', 3),
#  ('bescheiden.', 1),
#  ('Haben', 1),
#  ('Überwindung', 1),
#  ('Materialismus', 1),
#  ('Kritizismus', 1),
#  ('Vollendung', 2),
#  ('Nikaragua-Kanals', 1),
#  ('dargestellt.«', 1),
#  ('schwache', 2),
#  ('Versuche!', 1),
#  ('O', 2),
#  ('Magnet,', 8),
#  ('wann', 2),
#  ('Meister', 1),
#  ('erstehen,', 1),
#  ('Geruchsdrama', 1),
#  ('Zukunft', 5),
#  ('schafft!', 1),
#  ('Riechmann?', 1),
#  ('Ihm', 1),
#  ('mangelt', 1),
#  ('gestaltende', 1),
#  ('Sprache', 2),
#  ('ach,', 2),
#  ('kein', 5),
#  ('Duftkünstler?«', 1),
#  ('»Weil', 2),
#  ('bin,', 2),
#  ('schlechter.', 1),
#  ('Doch', 7),
#  ('dürfen', 2),
#  ('suchen,', 1),
#  ('greifen', 1),
#  ('zurück', 2),
#  ('Vergangenheit.«', 1),
#  ('bitte', 2),
#  ('Sie,', 4),
#  ('Shakespeare,', 1),
#  ('Goethe', 1),
#  ('...«', 3),
#  ('»Viel', 1),
#  ('veraltet,', 1),
#  ('nein', 1),
#  ('Anton', 1),
#  ('Feuerhase', 1),
#  ('Trauerspiel', 1),
#  ('›Die', 1),
#  ('letzte', 3),
#  ('Lokomotive‹!', 1),
#  ('Poesie!', 1),
#  ('Denken', 1),
#  ('Schlußszene', 1),
#  ('Brummer', 1),
#  ('Ododionbegleitung', 1),
#  ...]

# %%
book = spark.read.text("bisText.txt")

# %%
with open("stop_words_german.txt", "r") as f:
    text = f.read()
    stopwords = text.splitlines()

len(stopwords), stopwords[:15]
# Out:
# (592,
#  ['a',
#   'ab',
#   'aber',
#   'ach',
#   'acht',
#   'achte',
#   'achten',
#   'achter',
#   'achtes',
#   'ag',
#   'alle',
#   'allein',
#   'allem',
#   'allen',
#   'aller'])

# %%
from pyspark.sql.functions import split

lines = book.select(split(book.value, " ").alias("line"))
lines.show(5)
# Out:
# +--------------------+
# |                line|
# +--------------------+
# |     [Kurd, Laßwitz]|
# |                  []|
# |                  []|
# |[Bis, zum, Nullpu...|
# |                  []|
# +--------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import explode, col

words = lines.select(explode(col("line")).alias("word"))
words.show(15)
# Out:
# +---------+
# |     word|
# +---------+
# |     Kurd|
# |  Laßwitz|
# |         |
# |         |
# |      Bis|
# |      zum|
# |Nullpunkt|
# |      des|
# |    Seins|
# |         |
# |         |
# |Erzählung|
# |      aus|
# |      dem|
# |    Jahre|
# +---------+
# only showing top 15 rows

# %%
from pyspark.sql.functions import lower

words_lower = words.select(lower(col("word")).alias("word_lower"))
words_lower.show()
# Out:
# +----------+
# |word_lower|
# +----------+
# |      kurd|
# |   laßwitz|
# |          |
# |          |
# |       bis|
# |       zum|
# | nullpunkt|
# |       des|
# |     seins|
# |          |
# |          |
# | erzählung|
# |       aus|
# |       dem|
# |     jahre|
# |      2371|
# |          |
# |          |
# |          |
# |          |
# +----------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import regexp_extract

words_clean = words_lower.select(
    regexp_extract(col("word_lower"), "[a-z]+", 0).alias("word")
)

words_clean.show()
# Out:
# +---------+
# |     word|
# +---------+
# |     kurd|
# |       la|
# |         |
# |         |
# |      bis|
# |      zum|
# |nullpunkt|
# |      des|
# |    seins|
# |         |
# |         |
# |      erz|
# |      aus|
# |      dem|
# |    jahre|
# |         |
# |         |
# |         |
# |         |
# |         |
# +---------+
# only showing top 20 rows

# %%
words_nonull = words_clean.filter(col("word") != "")
words_nonull.show()
# Out:
# +--------------+
# |          word|
# +--------------+
# |          kurd|
# |            la|
# |           bis|
# |           zum|
# |     nullpunkt|
# |           des|
# |         seins|
# |           erz|
# |           aus|
# |           dem|
# |         jahre|
# |           das|
# |geruchsklavier|
# |      aromasia|
# |            sa|
# |            im|
# |        garten|
# |         ihres|
# |        hauses|
# |           und|
# +--------------+
# only showing top 20 rows

# %%
words_without_stopwords = words_nonull.filter(
    ~words_nonull.word.isin(stopwords))

words_count_before_removing = words_nonull.count()
words_count_after_removing = words_without_stopwords.count()

words_count_before_removing, words_count_after_removing
# Out:
# (12523, 5104)

# %%
words_count = (words_without_stopwords.groupby("word")
               .count()
               .orderBy("count", ascending=False)
               )

# %%
rank = 20
words_count.show(rank)
# Out:
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |   aromasia|   61|
# |     oxygen|   51|
# |     magnet|   42|
# |         mu|   38|
# |        ber|   35|
# |        gro|   22|
# |       welt|   21|
# |         gl|   20|
# |         st|   17|
# |       erde|   17|
# |    ododion|   16|
# |  aromasias|   15|
# |        sch|   15|
# |    meinung|   15|
# | menschheit|   14|
# |         kr|   13|
# |ffentlichen|   13|
# |       rief|   13|
# |        gef|   12|
# |        hei|   12|
# +-----------+-----+
# only showing top 20 rows
